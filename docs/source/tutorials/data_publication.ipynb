# %% [markdown]
# # Data publication

# %% [markdown]
# ## 1. Comparison
# *Compare data improvements with specifically dedicated scripts.*

# %% [markdown]
# ### 1.1. Matrix vs. Matrix
# Comparison of proximity matrices:
# - Plots either the ratio or the difference between two HiM matrices.
# - Plots both matrices together, with one in the upper triangle, and the other in the lower triangle.

# %%
usage: plot_compare2matrices [-h] [-O OUTPUTFOLDER] [-T1 INPUT1] [-T2 INPUT2]
                             [-U UNIQUEBARCODES] [--fontsize FONTSIZE]
                             [--axisLabel] [--axisTicks] [--ratio]
                             [--plottingFileExtension PLOTTINGFILEEXTENSION]
                             [--normalize NORMALIZE] [--pixelSize PIXELSIZE]
                             [--matrix_norm_mode MATRIX_NORM_MODE]
                             [--dist_calc_mode DIST_CALC_MODE]
                             [--proximity_threshold PROXIMITY_THRESHOLD]
                             [--cMax CMAX]
                             [--scalingParameter SCALINGPARAMETER]
                             [--shuffle SHUFFLE] [--cMin CMIN] [--cmap CMAP]

# %% [markdown]
# ### 1.2. Statistic comparison
# Compare PWD matrices from two experiments:
# - Pearson correlation in ensemble
# - Plots violin diagrams with the distribution of proximities/distances for each dataset

# %%
usage: plot_matrix_comparison [-h] [--input1 INPUT1] [--input2 INPUT2]
                              [--output OUTPUT] [--mode MODE] [--x_min X_MIN]
                              [--x_max X_MAX] [--max_distance MAX_DISTANCE]
                              [--scale SCALE]

# %% [markdown]
# ### 1.3. Multiple Hi-M matrices
# Visually, compare multiple Hi-M organisations (conditions/datasets) on the same graph.

# %%
usage: plot_n_him_matrices [-h] [-F ROOTFOLDER] [-O OUTPUTFOLDER]
                           [-P PARAMETERS] [-A LABEL] [-W ACTION]
                           [--fontsize FONTSIZE] [--axisLabel] [--axisTicks]
                           [--barcodes] [--scalingParameter SCALINGPARAMETER]
                           [--plottingFileExtension PLOTTINGFILEEXTENSION]
                           [--shuffle SHUFFLE] [--scalogram] [--type TYPE]
                           [--pixelSize PIXELSIZE] [--cAxis CAXIS] [--ratio]
                           [--normalizeMatrix]

# %% [markdown]
# ## 2. Data meaning
# *Promote your data to share your results.*

# %% [markdown]
# ### 2.1. Bootstrapping
# Estimation of the average pairwise distance structure and its statistical error.

# %%
# !plot_bootstrapping --input Trace_Trace_all_ROIs_filtered_beta_mask0_exp_ND_1_PDX1LR_Matrix_PWDscMatrix.npy -U Trace_Trace_all_ROIs_filtered_exocrine_mask0_exp_ND_3_PDX1LR_Matrix_uniqueBarcodes.ecsv --N_bootstrap 100

# %% [markdown]
# ### 2.2. Draw a 3D single cell
# Rebuild a structure from the average PWD.

# %%
usage: plot_single_cell [-h] [-F ROOTFOLDER] [-O OUTPUTFOLDER] [-P PARAMETERS]
                        [-A LABEL] [-W ACTION] [--fontsize FONTSIZE]
                        [--axisLabel] [--axisTicks] [--barcodes]
                        [--nRows NROWS] [--pixelSize PIXELSIZE]
                        [--maxDistance MAXDISTANCE]
                        [--plottingFileExtension PLOTTINGFILEEXTENSION]
                        [--shuffle SHUFFLE] [--ensembleMatrix]
                        [--plotHistogramMatrix] [--minNumberPWD MINNUMBERPWD]
                        [--threshold THRESHOLD]

# %% [markdown]
# ### 2.3.  Multi-way Measurement of Molecular interactions
#
# #### 2.3.1. **2-way** colocalization
# - Measurement of pairwise interactions conditional on an anchor
# - “How often is each locus close to a given locus of interest?”

# %%
# !plot_4m --input  merged_traces_filtered.ecsv --anchor 18 --cutoff 0.20 --bootstrapping_cycles 10 --output coloc_plot.png

# %% [markdown]
# #### 2.3.2. **3-way** colocalization
# - measurement of higher-order interactions (3-way)
# - "How often are two loci simultaneously close to the same anchor locus in a cell?"

# %%
# !trace_3way_coloc --input merged_traces_filtered.ecsv --cutoff 0.20 --bootstrapping_cycles 2 --anchor 25

# %% [markdown]
# - Adjusts the appearance settings of the `trace_3way_coloc` plots:

# %%
# !plot_3way_coloc --input path/to/matrix1.npy path/to/matrix2.npy
