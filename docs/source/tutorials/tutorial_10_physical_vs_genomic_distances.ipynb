# %% [markdown]
# # Tutorial 10: Calculate and fit physical versus genomic distance distribution
#
# This tutorial walks through the standard workflow for calculatng the physical versus genomic distance from a trace file.

# %% [markdown]
# ## Step 0: Set-up your data and output path

# %%
import os
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

#Set up your folder data and destination paths:

data_path = "/mnt/grey/DATA/users/zidoum/traceraptops/data/Boettiger/Replicate2"
dest_path = f"{data_path}/output"

# Cortex tissue from tutorials 1-5
input_trace = f"{dest_path}/merged_traces_filtered_all.ecsv"

print(f"Input trace: {input_trace}")
# Out:
# Input trace: /mnt/grey/DATA/users/zidoum/traceraptops/data/Boettiger/Replicate2/output/merged_traces_filtered_all.ecsv

# %% [markdown]
# ## Step 1: Calculate physical vs genomic distances

# %%
# !trace_physical_vs_genomic_distance --input {input_trace} --output {data_path}/physical_vs_genomic_distance_plot.png
# Out:
# ------- Running trace_merge.py --------
# This script will merge trace tables provided as inputs.
#
# usage: trace_merge [-h] [-T TRACES] [--pipe] [-N NAME] [-F FOLDER] [--verbose]
# trace_merge: error: unrecognized arguments: --input /mnt/grey/DATA/users/zidoum/traceraptops/data/Boettiger/Replicate2/output/merged_traces_filtered_all.ecsv --output /mnt/grey/DATA/users/zidoum/traceraptops/data/Boettiger/Replicate2/physical_vs_genomic_distance_plot.png

# %% [markdown]
# ## Step 2: Display results

# %%
plot_file = f"{data_path}/physical_vs_genomic_distance_plot.png"

img = mpimg.imread(plot_file)
fig, ax = plt.subplots(figsize=(12, 5))
ax.imshow(img)
ax.axis('off')
ax.set_title("4M plot: colocalization with anchor barcode 10", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 plot_file = f"{data_path}/physical_vs_genomic_distance_plot.png"
#       2
# ----> 3 img = mpimg.imread(plot_file)
#       4 fig, ax = plt.subplots(figsize=(12, 5))
#       5 ax.imshow(img)
#       6 ax.axis('off')
#
# File ~/Repositories/traceratops/.venv/lib/python3.11/site-packages/matplotlib/image.py:1587, in imread(fname, format)
#    1580 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1581     # Pillow doesn't handle URLs directly.
#    1582     raise ValueError(
#    1583         "Please open the URL for reading and pass the "
#    1584         "result to Pillow, e.g. with "
#    1585         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1586         )
# -> 1587 with img_open(fname) as image:
#    1588     return (_pil_png_to_float_array(image)
#    1589             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1590             pil_to_array(image))
#
# File ~/Repositories/traceratops/.venv/lib/python3.11/site-packages/PIL/ImageFile.py:138, in ImageFile.__init__(self, fp, filename)
#     135 self._fp: IO[bytes] | DeferredError
#     136 if is_path(fp):
#     137     # filename
# --> 138     self.fp = open(fp, "rb")
#     139     self.filename = os.fspath(fp)
#     140     self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/grey/DATA/users/zidoum/traceraptops/data/Boettiger/Replicate2/physical_vs_genomic_distance_plot.png'
